# %%
from unet import helper
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

from unet import data

# %%
df = data.dataframe()

# %%
df['label'].value_counts()
# Out:
# car             123358
# trafficlight     17253
# pedestrian       15541
# truck             7322
# biker             1676
# Name: label, dtype: int64

# %%
df['image_file'].value_counts().head
# Out:
# <bound method NDFrame.head of data/object-dataset/1478020419697386200.jpg              31
# data/object-dataset/1478020420705248954.jpg              31
# data/object-dataset/1478020420204575229.jpg              31
# data/object-dataset/1478020419204218613.jpg              30
# data/object-dataset/1478900835416176800.jpg              30
# data/object-dataset/1478020421703195424.jpg              29
# data/object-dataset/1478020422696366401.jpg              29
# data/object-dataset/1478900834273691602.jpg              29
# data/object-dataset/1478901306729719930.jpg              29
# data/object-dataset/1478900834844439436.jpg              28
# data/object-dataset/1478901406707009151.jpg              28
# data/object-dataset/1478899618570376846.jpg              27
# data/object-dataset/1478897856140609864.jpg              27
# data/object-dataset/1478899206669204813.jpg              27
# data/object-dataset/1478020421204833659.jpg              27
# data/object-dataset/1478897854426424817.jpg              27
# data/object-dataset/1478901404420687096.jpg              27
# data/object-dataset/1478020464703286921.jpg              27
# data/object-dataset/1478899784813936078.jpg              27
# data/object-dataset/1478900833701930539.jpg              27
# data/object-dataset/1478897855568054263.jpg              27
# data/object-dataset/1478901306159002960.jpg              27
# data/object-dataset/1478899619139789962.jpg              27
# data/object-dataset/1478901405562954996.jpg              26
# data/object-dataset/1478020456197466034.jpg              26
# data/object-dataset/1478901404993177118.jpg              26
# data/object-dataset/1478899619711375757.jpg              26
# data/object-dataset/1478020455703647227.jpg              26
# data/object-dataset/1478899621425948164.jpg              26
# data/object-dataset/1478020457203132106.jpg              26
#                                                          ..
# data/object-dataset/1478021028722210215.jpg               1
# data/object-dataset/1478895606401283532.jpg               1
# data/object-dataset/1478020810210446634.jpg               1
# data/object-dataset/1478020588209920760.jpg               1
# data/object-dataset/1478895692095310947.jpg               1
# data/object-dataset/1478021030716739507.jpg               1
# data/object-detection-crowdai/1479499224023568836.jpg     1
# data/object-dataset/1478897809864852144.jpg               1
# data/object-dataset/1478020577207993782.jpg               1
# data/object-dataset/1478895671527898117.jpg               1
# data/object-dataset/1478020585212162283.jpg               1
# data/object-dataset/1478895701806001301.jpg               1
# data/object-detection-crowdai/1479499082514554260.jpg     1
# data/object-dataset/1478901162194405823.jpg               1
# data/object-dataset/1478020584704349088.jpg               1
# data/object-dataset/1478901154766496595.jpg               1
# data/object-dataset/1478898439997888440.jpg               1
# data/object-dataset/1478898645091910760.jpg               1
# data/object-dataset/1478895750365858387.jpg               1
# data/object-dataset/1478020597703424604.jpg               1
# data/object-dataset/1478901050792719234.jpg               1
# data/object-dataset/1478895713803346841.jpg               1
# data/object-dataset/1478897547071651260.jpg               1
# data/object-detection-crowdai/1479503735828557704.jpg     1
# data/object-dataset/1478899874506839110.jpg               1
# data/object-detection-crowdai/1479503683325350519.jpg     1
# data/object-detection-crowdai/1479503668323191214.jpg     1
# data/object-dataset/1478020597210213075.jpg               1
# data/object-dataset/1478896614727827980.jpg               1
# data/object-detection-crowdai/1479503808333731714.jpg     1
# Name: image_file, dtype: int64>

# %%
image_factories = data.image_factories(df, 1000)

# %%
def mask_to_image(mask, color):
  image = np.zeros((mask.shape[0], mask.shape[1], 3), np.uint8)
  image[:] = color
  return cv2.bitwise_and(255, image, mask=mask)
  
def masks_to_image(masks, alpha=0.3):
  colors = get_spaced_colors(masks.shape[-1])
  image = np.zeros((masks.shape[0], masks.shape[1], 3), np.uint8)
  image[:,:,:] = 255
  
  for i in range(masks.shape[-1]):
    mask = masks[:,:,i]
    mask_image = mask_to_image(mask, colors[i])
    image = cv2.addWeighted(mask_image, alpha, image, 1 - alpha, 0, image)
    
  return image

def bounding_boxes_to_image(bounding_boxes):
  colors = get_spaced_colors(masks.shape[-1])
  labels = {
  'car': 0, 
  'pedestrian' : 1,
  'truck': 2,
  'trafficlight': 3,
  'biker': 4
  }

def get_spaced_colors(n):
  max_value = 16581375 #255**3
  interval = int(max_value / n)
  colors = [hex(I)[2:].zfill(6) for I in range(255, max_value + 255, interval)]
  
  return [(int(i[:2], 16), int(i[2:4], 16), int(i[4:], 16)) for i in colors]

# %%
### Plotting generator output
def display_image_and_mask(image_obj):
    image = image_obj.image
    image_mask = np.array(image_obj.image_mask, np.uint8)
    flat_mask = np.array(np.amax(image_mask, axis=2), np.uint8)
    
    f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 9))
    f.tight_layout()
    ax1.imshow(image)
    ax1.set_title('Original Image', fontsize=30)
    ax2.imshow(masks_to_image(image_mask, alpha=0.5))
    ax2.set_title('Mask', fontsize=30)
    ax3.imshow(cv2.bitwise_and(image,image,mask=flat_mask))
    ax3.set_title('Image^Mask', fontsize=30)
    plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)
    ax1.axis('off')
    ax2.axis('off')
    ax3.axis('off')
    plt.show()

# %%
image_factories = sorted(image_factories, key=lambda factory: len(factory.bounding_boxes))

for i in range(-1,0):
    image_obj = image_factories[i].image(augment=False)
    display_image_and_mask(image_obj)
