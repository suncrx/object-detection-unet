# %%
from unet import helper
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from unet import data
from unet.bounding_box import ImageFactory

# %%
df = data.dataframe()
df[df.frame.isin(["1478896689566229358.jpg"])]
# Out:
#                          frame                                   image_file  \
# 35035  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
# 35036  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
# 35037  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
# 35038  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
# 35039  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
# 35040  1478896689566229358.jpg  data/object-dataset/1478896689566229358.jpg
#
#               label  ymin  xmin  ymax  xmax
# 35035           car   456   290  1154  1304
# 35036           car   502  1154   682  1414
# 35037  trafficlight   264  1428   362  1474
# 35038           car   560  1460   632  1620
# 35039  trafficlight   414  1664   502  1716
# 35040           car   642  1838   992  1916

# %%
train_g, test_g = data.train_test_generator(1)
# u = df.frame.unique()
# for i in range(10):
#   matching_frames = df[df.frame.isin([u[i]])]
#   print(matching_frames.image_file.iloc[0])

# %%
i = 0
while (i < 100):
  i+=1
  print(next(test_g))
# Out:
# data/object-dataset/1478899984765169502.jpg
# data/object-dataset/1478899815092064712.jpg
# (array([[[[ 223.,  243.,  251.],
#          [ 235.,  253.,  255.],
#          [ 218.,  238.,  246.],
#          ...,
#          [ 182.,  164.,  112.],
#          [ 255.,  255.,  172.],
#          [ 255.,  255.,  179.]],
#
#         [[ 255.,  252.,  247.],
#          [ 255.,  254.,  249.],
#          [ 255.,  253.,  247.],
#          ...,
#          [ 255.,  245.,  139.],
#          [ 243.,  221.,  130.],
#          [ 255.,  238.,  125.]],
#
#         [[ 253.,  255.,  255.],
#          [ 253.,  255.,  255.],
#          [ 253.,  255.,  255.],
#          ...,
#          [ 255.,  254.,  149.],
#          [ 240.,  223.,  118.],
#          [ 255.,  243.,  113.]],
#
#         ...,
#         [[  46.,   47.,   52.],
#          [  47.,   48.,   53.],
#          [  48.,   49.,   54.],
#          ...,
#          [ 100.,  105.,  109.],
#          [  98.,  103.,  107.],
#          [ 100.,  105.,  109.]],
#
# ...
